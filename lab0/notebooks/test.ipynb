# %%
import requests 
import numpy as np

data = {
  "PassengerId": 709,
  "Pclass": 3,
  "Name": "Moubarek, Master. Halim Gonios (\"William George\")",
  "Sex": "male",
  "Age": 1,
  "SibSp": 1,
  "Parch": 1,
  "Ticket": "2661",
  "Fare": 15.2458,
  "Cabin": 'c22',
  "Embarked": "C",
  "Title": "Master",
  "FamilySize": 3,
  "IsAlone": 0,
  "Deck": "c",
  "TicketGroupSize": 2,
  "FarePerPerson": 5.081933333333333,
  "AgeBin": 1,
  "FareBin": 2,
  "Pclass_AgeBin": "3_1",
  "Sex_Pclass": "male_3",
  "CabinMissing": 1,
  "AgeMissing": 1,
  "Survived": 0
}

# Define the server URL
url = "http://localhost:8000/predict"

# Send the POST request
response = requests.post(url, json=data)

# Print the response
print("Response:", response.json())
# Out:
# Response: {'detail': 'Internal Server Error'}
